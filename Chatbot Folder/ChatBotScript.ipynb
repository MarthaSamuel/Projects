# %%
import nltk
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
import pickle
import numpy as np

from keras.models import load_model

# %%
model = load_model('chatbot_model.h5')

# %%
import json
import random
intents = json.loads(open('commands.json').read())
words = pickle.load(open('words.pkl','rb'))
classes = pickle.load(open('classes.pkl','rb'))

# %%
def clean_up_sentence(sentence):
    # tokenize 
    sentence_words = nltk.word_tokenize(sentence)
    # stemmming
    sentence_words = [lemmatizer.lemmatize(word.lower()) for word in sentence_words]
    return sentence_words

# %%
# return bag of words array

def bow(sentence, words, show_details=True):
    # tokenize the pattern
    sentence_words = clean_up_sentence(sentence)
    # bag of words
    bag = [0]*len(words)  
    for s in sentence_words:
        for i,w in enumerate(words):
            if w == s: 
                
                bag[i] = 1
                if show_details:
                    print ("found in bag: %s" % w)
    return(np.array(bag))

# %%
def predict_class(sentence, model):
    # filter out predictions based on below threshold
    p = bow(sentence, words,show_details=False)
    res = model.predict(np.array([p]))[0]
    ERROR_THRESHOLD = 0.25
    results = [[i,r] for i,r in enumerate(res) if r>ERROR_THRESHOLD]
    # sort by strength of probability
    results.sort(key=lambda x: x[1], reverse=True)
    return_list = []
    for r in results:
        return_list.append({"intent": classes[r[0]], "probability": str(r[1])})
    return return_list

# %%
def getResponse(ints, intents_json):
    tag = ints[0]['intent']
    list_of_intents = intents_json['intents']
    for i in list_of_intents:
        if(i['tag']== tag):
            result = random.choice(i['responses'])
            break
    return result

# %%
def chatbot_response(msg):
    ints = predict_class(msg, model)
    res = getResponse(ints, intents)
    return res

# %%
#!pip install SpeechRecognition
#!pip install pyaudio
import speech_recognition as sr

# %%
#take Speech Inputs
while(1):
    import speech_recognition as sr
    r = sr.Recognizer()
    audio = ''
    with sr.Microphone() as source:
        print("Speak...")
        audio = r.listen(source, phrase_time_limit=5)
    print("Stop.")
    try:
        text = r.recognize_google(audio,language='en-US')
        print("You : ", text)
        chatbot_response(text)
        res = chatbot_response(text)
        print("Bot: " + res + '\n\n')
    except:
        print("Could not understand your audio, PLease try again!")
# Out:
# Speak...
# Stop.
# You :  hello
# Bot: Good to see you again
#
#
# Speak...
# Stop.
# You :  hai
# Bot: Good to see you again
#
#
# Speak...
# Stop.
# You :  how are you
# Bot: Hi there, how can I help?
#
#
# Speak...
# Stop.
# You :  do you understand English
# Bot: I can guide you through Adverse drug reaction list, Blood pressure tracking, Hospitals and Pharmacies
#
#
# Speak...
# Stop.
# You :  blood pressure tracking
# Bot: Navigating to Blood Pressure module
#
#
# Speak...
# Stop.
# You :  how to navigate blood pressure module
# Bot: Navigating to Blood Pressure module
#
#
# Speak...
# Stop.
# You :  please navigate blood pressure module
# Bot: Navigating to Blood Pressure module
#
#
# Speak...
# Stop.
# You :  Hospital
# Bot: Please provide hospital name or location
#
#
# Speak...
# Stop.
# You :  Apollo Hospital
# Bot: Please provide hospital name or location
#
#
# Speak...
# Stop.
# You :  Delhi
# Bot: Good to see you again
#
#
# Speak...
# Stop.
# You :  America
# Bot: Hello, thanks for asking
#
#
# Speak...
# Stop.
# You :  a
# Bot: Hello, thanks for asking
#
#
# Speak...
# Stop.
# You :  may I know your name
# Bot: Hello, thanks for asking
#
#
# Speak...
# Stop.
# You :  are you chatbot
# Bot: Good to see you again
#
#
# Speak...
# Stop.
# You :  bye
# Bot: See you!
#
#
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# You :  hello
# Bot: Hi there, how can I help?
#
#
# Speak...
# Stop.
# You :  yah Kiran so I am I am just in a you can see admin and one more thing I would like
# Bot: Have a nice day
#
#
# Speak...
# Stop.
# You :  as today is the last you know station for them so it might be possible
# Bot: Good to see you again
#
#
# Speak...
# Stop.
# You :  ok so
# Bot: Good to see you again
#
#
# Speak...
# Stop.
# You :  call a of course I'll try that if they would have some queries so of course
# Bot: Any time!
#
#
# Speak...
# Stop.
# You :  we all ok so it might get over in 3 hours so just be there
# Bot: Good to see you again
#
#
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# You :  thank you
# Bot: My pleasure
#
#
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# You :  hi Kiran
# Bot: Good to see you again
#
#
# Speak...
# Stop.
# You :  thank you
# Bot: Any time!
#
#
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# You :  hello everyone I doctor Aakash once again welcome all of you in our last session of
# Bot: Good to see you again
#
#
# Speak...
# Stop.
# You :  NLP and speech recognition
# Bot: Good to see you again
#
#
# Speak...
# Stop.
# You :  hope you all are doing fantastic you all are safe healthy
# Bot: Good to see you again
#
#
# Speak...
# Stop.
# You :  so guys what's up and
# Bot: I can guide you through Adverse drug reaction list, Blood pressure tracking, Hospitals and Pharmacies
#
#
# Speak...
# Stop.
# You :  do you have anything to start with you have anything
# Bot: Offering support for Adverse drug reaction, Blood pressure, Hospitals and Pharmacies
#
#
# Speak...
# Stop.
# You :  you have anything to say
# Bot: I can guide you through Adverse drug reaction list, Blood pressure tracking, Hospitals and Pharmacies
#
#
# Speak...
# Stop.
# You :  forum is open to all of you
# Bot: I can guide you through Adverse drug reaction list, Blood pressure tracking, Hospitals and Pharmacies
#
#
# Speak...
# Stop.
# You :  meanwhile our other friends are
# Bot: Hi there, how can I help?
#
#
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# You :  yes Mata please go ahead
# Bot: Good to see you again
#
#
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# You :  ok B function
# Bot: Hi there, how can I help?
#
#
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# You :  ok
# Bot: Hello, thanks for asking
#
#
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# You :  ok it expects a string ok seal you can do one thing
# Bot: I can guide you through Adverse drug reaction list, Blood pressure tracking, Hospitals and Pharmacies
#
#
# Speak...
# Stop.
# You :  just give me a second you can do one thing
# Bot: I can guide you through Adverse drug reaction list, Blood pressure tracking, Hospitals and Pharmacies
#
#
# Speak...
# Stop.
# You :  I am telling you the reason actually is the sometime you know
# Bot: Hello, thanks for asking
#
#
# Speak...
# Stop.
# You :  right
# Bot: Good to see you again
#
#
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# You :  time there will be some of the UNO what we can
# Bot: Offering support for Adverse drug reaction, Blood pressure, Hospitals and Pharmacies
#
#
# Speak...
# Stop.
# You :  characters that that want to be
# Bot: My pleasure
#
#
# Speak...
# Stop.
# You :  supposed to be you know a free means in the human language it is trained but when it come
# Bot: I can guide you through Adverse drug reaction list, Blood pressure tracking, Hospitals and Pharmacies
#
#
# Speak...
# Stop.
# You :  table by machine
# Bot: Hello, thanks for asking
#
#
# Speak...
# Stop.
# You :  remember if you get such error while you are doing you know NLP or some sort of
# Bot: Hi there, how can I help?
#
#
# Speak...
# Stop.
# You :  text clean up right ba2year Sourav you always try to convert the
# Bot: See you!
#
#
# Speak...
# Stop.
# You :  ab column as an spring ok so it will be the safety step so before
# Bot: Good to see you again
#
#
# Speak...
# Stop.
# You :  hair like you are using this you know I am quite sure that you
# Bot: Hi there, how can I help?
#
#
# Speak...
# Stop.
# You :  you have cleaned your to eat as per your you know
# Bot: Bye! Come back again soon.
#
#
# Speak...
# Stop.
# You :  the treat column name like we have done in our teeth clean up and
# Bot: Good to see you again
#
#
# Speak...
# Stop.
# You :  get column width of the data frame as it is right
# Bot: Navigating to Adverse drug reaction module
#
#
# Speak...
# Stop.
# You :  yeah so in some of the cases Tamasha it works ok
# Bot: Hi there, how can I help?
#
#
# Speak...
# Stop.
# You :  but if in case if it won't work because you never know that what sort of
# Bot: Offering support for Adverse drug reaction, Blood pressure, Hospitals and Pharmacies
#
#
# Speak...
# Stop.
# You :  just you need to put this
# Bot: Have a nice day
#
#
# Speak...
# Stop.
# You :  sharing that line ok because I have tried something and the same error
# Bot: My pleasure
#
#
# Speak...
# Stop.
# You :  use this line only
# Bot: Hi there, how can I help?
#
#
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# You :  I hope then it will work
# Bot: Hello, thanks for asking
#
#
# Speak...
# Stop.
# You :  HD I was doing one of the project
# Bot: Good to see you again
#
#
# Speak...
# Stop.
# You :  I am I am just saying here only on the charges give me a second I am typing it up
# Bot: Navigating to Adverse drug reaction module
#
#
# Speak...
# Stop.
# You :  please have a look so here are you you just need to you know
# Bot: Hi there, how can I help?
#
#
# Speak...
# Stop.
# You :  you just need to replace this review by whatever the text you are working
# Bot: Hello, thanks for asking
#
#
# Speak...
# Stop.
# You :  objective the column you are targeting in my case it work it was review
# Bot: Hi there, how can I help?
#
#
# Speak...
# Stop.
# You :  review and my data frame name was data frame that ok
# Bot: Any time!
#
#
# Speak...
# Stop.
# You :  now can you can you see that
# Bot: Have a nice day
#
#
# Speak...
# Stop.
# You :  in case of female
# Bot: Hi there, how can I help?
#
#
# Speak...
# Stop.
# You :  your Twitter are you know your review or your test or whatever
# Bot: Hello, thanks for asking
#
#
# Speak...
# Stop.
# You :  frame in my case it was a win your case it could be
# Bot: I can guide you through Adverse drug reaction list, Blood pressure tracking, Hospitals and Pharmacies
#
#
# Speak...
# Stop.
# You :  Mata you can try data definitely
# Bot: Offering support for Adverse drug reaction, Blood pressure, Hospitals and Pharmacies
#
#
# Speak...
# Stop.
# You :  yes so it's a very unique good start for our today station
# Bot: Any time!
#
#
# Speak...
# Stop.
# You :  like to
# Bot: Hi there, how can I help?
#
#
# Speak...
# Stop.
# You :  SOL last date I think that you know you will get 12 week after
# Bot: Any time!
#
#
# Speak...
# Stop.
# You :  battery issue can ask from Unity for someone
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# You :  so they will help you into the
# Bot: I can guide you through Adverse drug reaction list, Blood pressure tracking, Hospitals and Pharmacies
#
#
# Speak...
# Stop.
# You :  for mice pigeon that once your module will get completed after one
# Bot: Any time!
#
#
# Speak...
# Stop.
# You :  time of one week
# Bot: Bye! Come back again soon.
#
#
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# You :  ok no worries Amitabh
# Bot: Hello, thanks for asking
#
#
# Speak...
# Stop.
# You :  hey what
# Bot: Hello, thanks for asking
#
#
# Speak...
# Stop.
# You :  oh my God
# Bot: Hi there, how can I help?
#
#
# Speak...
# Stop.
# You :  I am so so so sorry Amitabh
# Bot: Hi there, how can I help?
#
#
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# You :  I am so sorry listening this I am so sorry
# Bot: Hello, thanks for asking
#
#
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# You :  gas can be have just two minutes of peace for Amitabh
# Bot: I can guide you through Adverse drug reaction list, Blood pressure tracking, Hospitals and Pharmacies
#
#
# Speak...
# Stop.
# You :  just to pass our condolences
# Bot: Good to see you again
#
#
# Speak...
# Stop.
# You :  everything across you
# Bot: Hello, thanks for asking
#
#
# Speak...
# Stop.
# You :  to you within 2 min
# Bot: See you!
#
#
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# You :  thanks everyone stay strong Amitabh
# Bot: My pleasure
#
#
# Speak...
# Stop.
# You :  let me know for any help
# Bot: Offering support for Adverse drug reaction, Blood pressure, Hospitals and Pharmacies
#
#
# Speak...
# Stop.
# You :  ok so
# Bot: Hello, thanks for asking
#
#
# Speak...
# Stop.
# You :  that's life
# Bot: Any time!
#
#
# Speak...
# Stop.
# You :  mobile so guys so regarding the commission
# Bot: Hello, thanks for asking
#
#
# Speak...
# Stop.
# You :  5 days before the next schedule classroom
# Bot: Hi there, how can I help?
#
#
# Speak...
# Stop.
# You :  you will definitely get one week to do so 61
# Bot: Offering support for Adverse drug reaction, Blood pressure, Hospitals and Pharmacies
#
#
# Speak...
# Stop.
# You :  we have done last week 1 we are going to discuss today that is chat
# Bot: Hello, thanks for asking
#
#
# Speak...
# Stop.
# You :  will be left that is Wikipedia
# Bot: My pleasure
#
#
# Speak...
# Stop.
# You :  toxicities you are so that I think that you can do by your own it's a simple one
# Bot: Any time!
#
#
# Speak...
# Stop.
# You :  what we are going to do today only so I hope that you all would able to submit deposit
# Bot: I can guide you through Adverse drug reaction list, Blood pressure tracking, Hospitals and Pharmacies
#
#
# Speak...
# Stop.
# You :  and not just fake of sorry not just sake of submission
# Bot: Good to see you again
#
#
# Speak...
# Stop.
# You :  ok so guys anything you want to understand or you want to ask from LA
# Bot: Have a nice day
#
#
# Speak...
# Stop.
# You :  guys do you have any query regarding that so you can ask me
# Bot: I can guide you through Adverse drug reaction list, Blood pressure tracking, Hospitals and Pharmacies
#
#
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# You :  otherwise I'll stay Tobago and discuss about chatbot
# Bot: Hello, thanks for asking
#
#
# Speak...
# Stop.
# You :  chatbot
# Bot: Hi there, how can I help?
#
#
# Speak...
# Stop.
# You :  yes survey paper is just mean tidewater
# Bot: Good to see you again
#
#
# Speak...
# Stop.
# You :  so I can show you one
# Bot: Offering support for Adverse drug reaction, Blood pressure, Hospitals and Pharmacies
#
#
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# You :  I am just showing you what we can call it as
# Bot: I can guide you through Adverse drug reaction list, Blood pressure tracking, Hospitals and Pharmacies
#
#
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# You :  so it actually means that you know whatever the work that has been done
# Bot: My pleasure
#
#
# Speak...
# Stop.
# You :  you just need to list it out ok and you need to present that
# Bot: Happy to help!
#
#
# Speak...
# Stop.
# You :  freedom technique that has been involved
# Bot: Happy to help!
#
#
# Speak...
# Stop.
# You :  that particular case
# Bot: My pleasure
#
#
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# You :  so this is my
# Bot: Hi there, how can I help?
#
#
# Speak...
# Stop.
# You :  I have published date as a research paper
# Bot: Hello, thanks for asking
#
#
# Speak...
# Stop.
# You :  we talked about
# Bot: Hello, thanks for asking
#
#
# Speak...
# Stop.
# You :  no this is not that one ok so I don't know why I am not getting it
# Bot: Hello, thanks for asking
#
#
# Speak...
# Stop.
# You :  the local copy of it so
# Bot: Hello, thanks for asking
#
#
# Speak...
# Stop.
# You :  anyway so I will I will just you know share with you the paper ok
# Bot: Good to see you again
#
#
# Speak...
# Stop.
# You :  search in the brake and address and share with you
# Bot: Hello, thanks for asking
#
#
# Speak...
# Stop.
# You :  about you know that in survey paper you are going to talk about
# Bot: Hello, thanks for asking
#
#
# Speak...
# Stop.
# You :  end
# Bot: Hi there, how can I help?
#
#
# Speak...
# Stop.
# You :  review we include 10n years of work ok
# Bot: Hello, thanks for asking
#
#
# Speak...
# Stop.
# You :  today if you can see that your last 10 years what sort of work
# Bot: Offering support for Adverse drug reaction, Blood pressure, Hospitals and Pharmacies
#
#
# Speak...
# Stop.
# You :  actually a follows one of the ab
# Bot: Please provide pharmacy name
#
#
# Speak...
# Stop.
# You :  where you can have introduction Metrology
# Bot: Offering support for Adverse drug reaction, Blood pressure, Hospitals and Pharmacies
#
#
# Speak...
# Stop.
# You :  and you need to give all those references and
# Bot: See you!
#
#
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# You :  no so don't go for a walk for those research paper where you
# Bot: Any time!
#
#
# Speak...
# Stop.
# You :  it is not worth the den
# Bot: Good to see you again
#
#
# Speak...
# Stop.
# You :  ok
# Bot: Good to see you again
#
#
# Speak...
# Stop.
# You :  and
# Bot: Good to see you again
#
#
# Speak...
# Stop.
# You :  standard you did you you need to pay $32 Rs you will be get
# Bot: I can guide you through Adverse drug reaction list, Blood pressure tracking, Hospitals and Pharmacies
#
#
# Speak...
# Stop.
# You :  what do you mean by Singh
# Bot: I can guide you through Adverse drug reaction list, Blood pressure tracking, Hospitals and Pharmacies
#
#
# Speak...
# Stop.
# You :  yes you don't go for it then
# Bot: Any time!
#
#
# Speak...
# Stop.
# You :  go for it you can just you know I told you today you can go ahead with the scholar dot
# Bot: Offering support for Adverse drug reaction, Blood pressure, Hospitals and Pharmacies
#
#
# Speak...
# Stop.
# You :  and there you will find lot of
# Bot: Good to see you again
#
#
# Speak...
# Stop.
# You :  search paper
# Bot: Please provide pharmacy name
#
#
# Speak...
# Stop.
# You :  ok
# Bot: Hi there, how can I help?
#
#
# Speak...
# Stop.
# You :  news
# Bot: Good to see you again
#
#
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# You :  yes so you can check it up however I have already shared that project with all of
# Bot: I can guide you through Adverse drug reaction list, Blood pressure tracking, Hospitals and Pharmacies
#
#
# Speak...
# Stop.
# You :  I think yeah review analysis so you can just refer to this folder
# Bot: I can guide you through Adverse drug reaction list, Blood pressure tracking, Hospitals and Pharmacies
#
#
# Speak...
# Stop.
# You :  solution
# Bot: Hello, thanks for asking
#
#
# Speak...
# Stop.
# You :  so guys I don't think that you do have any question is it now
# Bot: Offering support for Adverse drug reaction, Blood pressure, Hospitals and Pharmacies
#
#
# Speak...
# Stop.
# You :  let me start my station and ok so our
# Bot: Happy to help!
#
#
# Speak...
# Stop.
# You :  R1 s
# Bot: Hello, thanks for asking
#
#
# Speak...
# Stop.
# You :  chatbot
# Bot: Hello, thanks for asking
#
#
# Speak...
# Stop.
# You :  how to
# Bot: Hi there, how can I help?
#
#
# Speak...
# Stop.
# You :  machine learning model
# Bot: Hi there, how can I help?
#
#
# Speak...
# Stop.
# You :  CT Dallas plane
# Bot: Hi there, how can I help?
#
#
# Speak...
# Stop.
# You :  right so that's what a we are target
# Bot: My pleasure
#
#
# Speak...
# Stop.
# You :  so I start but I think you know it is one of the most
# Bot: Good to see you again
#
#
# Speak...
# Stop.
# You :  most awaited you know things to do in due course of NLP
# Bot: Offering support for Adverse drug reaction, Blood pressure, Hospitals and Pharmacies
#
#
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# You :  we need to create this much of this much of
# Bot: Navigating to Adverse drug reaction module
#
#
# Speak...
# Stop.
# You :  it's ok
# Bot: Any time!
#
#
# Speak...
# Stop.
# You :  I am sorry
# Bot: Hello, thanks for asking
#
#
# Speak...
# Stop.
# You :  so these are the files which are required for the chatbot
# Bot: Hi there, how can I help?
#
#
# Speak...
# Stop.
# You :  and that is the reason you know I want this to be done here only
# Bot: I can guide you through Adverse drug reaction list, Blood pressure tracking, Hospitals and Pharmacies
#
#
# Speak...
# Stop.
# You :  and you can a follow me so you know we can do life this project
# Bot: I can guide you through Adverse drug reaction list, Blood pressure tracking, Hospitals and Pharmacies
#
#
# Speak...
# Stop.
# You :  and of course then you will
# Bot: Hi there, how can I help?
#
#
# Speak...
# Stop.
# You :  will create one chatbot so guys please you know I just have a look here
# Bot: Good to see you again
#
#
# Speak...
# Stop.
# You :  the very first fibre you need for any chatbot it should be
# Bot: Happy to help!
#
#
# Speak...
# Stop.
# You :  which would
# Bot: Hi there, how can I help?
#
#
# Speak...
# Stop.
# You :  predefined patterns and respond
# Bot: Hi there, how can I help?
#
#
# Speak...
# Stop.
# You :  ok and that file you must have in the format of
# Bot: My pleasure
#
#
# Speak...
# Stop.
# You :  like I always told you guys that you know any such application like chatboard it
# Bot: Happy to help!
#
#
# Speak...
# Stop.
# You :  it would need
# Bot: Hi there, how can I help?
#
#
# Speak...
# Stop.
# You :  as a data scientist on machine learning practitioner and it would also required
# Bot: Navigating to Adverse drug reaction module
#
#
# Speak...
# Stop.
# You :  so machine learning engineer
# Bot: Hello, thanks for asking
#
#
# Speak...
# Stop.
# You :  expected to have a software development background
# Bot: Navigating to Adverse drug reaction module
#
#
# Speak...
# Stop.
# You :  a i
# Bot: Hi there, how can I help?
#
#
# Speak...
# Stop.
# You :  one of the panelist in one of the conference so you know there we have discussed
# Bot: Good to see you again
#
#
# Speak...
# Stop.
# You :  so today I can share with you that what is the difference between you know
# Bot: I can guide you through Adverse drug reaction list, Blood pressure tracking, Hospitals and Pharmacies
#
#
# Speak...
# Stop.
# You :  ok let me
# Bot: My pleasure
#
#
# Speak...
# Stop.
# You :  email architect
# Bot: Good to see you again
#
#
# Speak...
# Stop.
# You :  and
# Bot: Hi there, how can I help?
#
#
# Speak...
# Stop.
# You :  applied
# Bot: Hi there, how can I help?
#
#
# Speak...
# Stop.
# You :  data scientist
# Bot: Good to see you again
#
#
# Speak...
# Stop.
# You :  learning engineer
# Bot: Good to see you again
#
#
# Speak...
# Stop.
# You :  senior
# Bot: Hello, thanks for asking
#
#
# Speak...
# Stop.
# You :  so these are the the positions what we have actually
# Bot: Hello, thanks for asking
#
#
# Speak...
# Stop.
# You :  ml architect is a someone who would be expected to
# Bot: Hi there, how can I help?
#
#
# Speak...
# Stop.
# You :  disposal in developing models handling teams
# Bot: Hi there, how can I help?
#
#
# Speak...
# Stop.
# You :  some sort of you know project management experience in aml
# Bot: I can guide you through Adverse drug reaction list, Blood pressure tracking, Hospitals and Pharmacies
#
#
# Speak...
# Stop.
# You :  applied data scientist so the role comes for Applied data scientist
# Bot: Please provide hospital name or location
#
#
# Speak...
# Stop.
# You :  people who actually
# Bot: Hello, thanks for asking
#
#
# Speak...
# Stop.
# You :  search
# Bot: Please provide pharmacy name
#
#
# Speak...
# Stop.
# You :  develop machine learning model so let me tell you what amount
# Bot: Offering support for Adverse drug reaction, Blood pressure, Hospitals and Pharmacies
#
#
# Speak...
# Stop.
# You :  OK what amount of work you are actually going to
# Bot: Hi there, how can I help?
#
#
# Speak...
# Stop.
# You :  speed into applied data scientist of course you should start with the entry level
# Bot: Navigating to Blood Pressure module
#
#
# Speak...
# Stop.
# You :  bache
# Bot: Hello, thanks for asking
#
#
# Speak...
# Stop.
# You :  this particular role
# Bot: Good to see you again
#
#
# Speak...
# Stop.
# You :  write applied data scientist and applied data scientist is responsible
# Bot: Good to see you again
#
#
# Speak...
# Stop.
# You :  file that you know to developing the model to coming up and you know
# Bot: My pleasure
#
#
# Speak...
# Stop.
# You :  the accuracy of the model you know suggesting it is his or her expertise
# Bot: Good to see you again
#
#
# Speak...
# Stop.
# You :  job role and responsibility would come under Predator scientist then we have machine
# Bot: Hello, thanks for asking
#
#
# Speak...
# Stop.
# You :  learning engineer would be expected to coming from software development background
# Bot: See you!
#
#
# Speak...
# Stop.
# You :  of course it includes the web development is well because nowadays most of the software
# Bot: Good to see you again
#
#
# Speak...
# Stop.
# You :  machine learning engineer would held responsible for the production of this
# Bot: Please provide pharmacy name
#
#
# Speak...
# Stop.
# You :  you are a going to built up on machine learning engineer would
# Bot: Good to see you again
#
#
# Speak...
# Stop.
# You :  that model in the production will be taking care of the execution of that model
# Bot: Any time!
#
#
# Speak...
# Stop.
# You :  least one of the domain where it's not like that you have you no develop the something you will
# Bot: Any time!
#
#
# Speak...
# Stop.
# You :  it will be the continuation in the job every day you need to monitor the performance
# Bot: Hello, thanks for asking
#
#
# Speak...
# Stop.
# You :  enough fine tune the things out there and then only you know
# Bot: Hello, thanks for asking
#
#
# Speak...
# Stop.
# You :  300 about the life cycle of any of the project on any of the product
# Bot: Good to see you again
#
#
# Speak...
# Stop.
# You :  machine learning engineer would be expected more over the
# Bot: Hello, thanks for asking
#
#
# Speak...
# Stop.
# You :  deploying a developing the machine learning
# Bot: Good to see you again
#
#
# Speak...
# Stop.
# You :  I want you to pay attention on these two roll because these two Rose I found
# Bot: See you!
#
#
# Speak...
# Stop.
# You :  ask me that you know what is the difference between these two role and inspect if I would
# Bot: I can guide you through Adverse drug reaction list, Blood pressure tracking, Hospitals and Pharmacies
#
#
# Speak...
# Stop.
# You :  I was you know just before this week I was also
# Bot: Good to see you again
#
#
# Speak...
# Stop.
# You :  confusion right but the moment I I have joined that you know station
# Bot: Any time!
#
#
# Speak...
# Stop.
# You :  my inputs across the US a we got that inside that machine learning in
# Bot: My pleasure
#
#
# Speak...
# Stop.
# You :  factor towards the development and deployment of the model in production when I
# Bot: Hi there, how can I help?
#
#
# Speak...
# Stop.
# You :  walking as an web app for deploying agent product ok so
# Bot: Please provide hospital name or location
#
#
# Speak...
# Stop.
# You :  data engineer and data analyst there are more you know expected to do the
# Bot: Hi there, how can I help?
#
#
# Speak...
# Stop.
# You :  data collection
# Bot: Good to see you again
#
#
# Speak...
# Stop.
# You :  data preprocessing so I hope my time and again die I told you
# Bot: Have a nice day
#
#
# Speak...
# Stop.
# You :  you know that
# Bot: My pleasure
#
#
# Speak...
# Stop.
# You :  you get csv file I don't know you have put this heart across on
# Bot: I can guide you through Adverse drug reaction list, Blood pressure tracking, Hospitals and Pharmacies
#
#
# Speak...
# Stop.
# You :  I hope that few of you had already know about it that csv file
# Bot: Any time!
#
#
# Speak...
# Stop.
# You :  come up with
# Bot: Hello, thanks for asking
#
#
# Speak...
# Stop.
# You :  for you as a beginner you think that even if you have a data set it's a challenge to
# Bot: My pleasure
#
#
# Speak...
# Stop.
# You :  coming up with that with that csv file would be one of the greatest challenge
# Bot: Any time!
#
#
# Speak...
# Stop.
# You :  these guys are going to play with you know you
# Bot: Good to see you again
#
#
# Speak...
# Stop.
# You :  data means of data structure nothing
# Bot: Navigating to Adverse drug reaction module
#
#
# Speak...
# Stop.
# You :  they can't ok so they just you no play with the data analysed
# Bot: I can guide you through Adverse drug reaction list, Blood pressure tracking, Hospitals and Pharmacies
#
#
# Speak...
# Stop.
# You :  apply some sort of UNO data engineering techniques data
# Bot: Navigating to Adverse drug reaction module
#
#
# Speak...
# Stop.
# You :  and you know come up is much data set what is applied data scientist
# Bot: Offering support for Adverse drug reaction, Blood pressure, Hospitals and Pharmacies
#
#
# Speak...
# Stop.
# You :  in their problem
# Bot: Good to see you again
#
#
# Speak...
# Stop.
# You :  I hope you got my point now coming back to our problem statement of chatbot
# Bot: Bye! Come back again soon.
#
#
# Speak...
# Stop.
# You :  Jesus and it will be taken care by someone
# Bot: Hello, thanks for asking
#
#
# Speak...
# Stop.
# You :  machine learning engineer write for us
# Bot: Good to see you again
#
#
# Speak...
# Stop.
# You :  suggesting damned and what sort of predefined patterns and responses you
# Bot: I can guide you through Adverse drug reaction list, Blood pressure tracking, Hospitals and Pharmacies
#
#
# Speak...
# Stop.
# You :  chatbot is basically you know a build up on few categories like you
# Bot: Hello, thanks for asking
#
#
# Speak...
# Stop.
# You :  hospitals include some sort of blood pressure
# Bot: Navigating to Blood Pressure module
#
#
# Speak...
# Stop.
# You :  these health issues it is based upon this is for a one of the
# Bot: Good to see you again
#
#
# Speak...
# Stop.
# You :  the protec same similarly whatever the domain
# Bot: Hi there, how can I help?
#
#
# Speak...
# Stop.
# You :  your commands will be
# Bot: Hello, thanks for asking
#
#
# Speak...
# Stop.
# You :  for that particular chatbot and that is a
# Bot: My pleasure
#
#
# Speak...
# Stop.
# You :  and you know this sort of stuff to come up with some sort of data file with
# Bot: Have a nice day
#
#
# Speak...
# Stop.
# You :  ok you need to come up with that particular you know inputs
# Bot: Any time!
#
#
# Speak...
# Stop.
# You :  there are a lot of people who would involve into dad for example if 1
# Bot: Hello, thanks for asking
#
#
# Speak...
# Stop.
# You :  chatbot for aviation or airline you know reservation for
# Bot: Happy to help!
#
#
# Speak...
# Stop.
# You :  commands would be a line into that domain
# Bot: Happy to help!
#
#
# Speak...
# Stop.
# You :  you need to pay attention parallel you one that we have
# Bot: My pleasure
#
#
# Speak...
# Stop.
# You :  Sofia targeting this domain at the same time you can also think
# Bot: Offering support for Adverse drug reaction, Blood pressure, Hospitals and Pharmacies
#
#
# Speak...
# Stop.
# You :  follow the same pipeline for any other chatbot project what you are
# Bot: Hi there, how can I help?
#
#
# Speak...
# Stop.
# You :  but you should be very careful that you must have all this file ready with you
# Bot: Offering support for Adverse drug reaction, Blood pressure, Hospitals and Pharmacies
#
#
# Speak...
# Stop.
# You :  number 1 number 2
# Bot: Good to see you again
#
#
# Speak...
# Stop.
# You :  I will be coming on this file later on then you you must have one pickle file
# Bot: Have a nice day
#
#
# Speak...
# Stop.
# You :  aware about why do we have in a pickle library in Python why do have
# Bot: Good to see you again
#
#
# Speak...
# Stop.
# You :  it actually you know it is one of the Stored object with includes some of the
# Bot: I can guide you through Adverse drug reaction list, Blood pressure tracking, Hospitals and Pharmacies
#
#
# Speak...
# Stop.
# You :  again and again ok this word should.be ke ALLEN classes dot PKL
# Bot: Hello, thanks for asking
#
#
# Speak...
# Stop.
# You :  this will contain what it will contain all the words
# Bot: I can guide you through Adverse drug reaction list, Blood pressure tracking, Hospitals and Pharmacies
#
#
# Speak...
# Stop.
# You :  that will help you to input the list of vocabulary
# Bot: Offering support for Adverse drug reaction, Blood pressure, Hospitals and Pharmacies
#
#
# Speak...
# Stop.
# You :  words you think that will that will fall under your
# Bot: My pleasure
#
#
# Speak...
# Stop.
# You :  get confused as hell you are going to ok
# Bot: Good to see you again
#
#
# Speak...
# Stop.
# You :  and you can say that command will be hi ok this will be the this might be
# Bot: Offering support for Adverse drug reaction, Blood pressure, Hospitals and Pharmacies
#
#
# Speak...
# Stop.
# You :  any user if it would be interacting with the you know that board
# Bot: Any time!
#
#
# Speak...
# Stop.
# You :  then you can just say that you know your dad
# Bot: I can guide you through Adverse drug reaction list, Blood pressure tracking, Hospitals and Pharmacies
#
#
# Speak...
# Stop.
# You :  chatbot for response like hai
# Bot: Hi there, how can I help?
#
#
# Speak...
# Stop.
# You :  help you
# Bot: Offering support for Adverse drug reaction, Blood pressure, Hospitals and Pharmacies
#
#
# Speak...
# Stop.
# You :  is you can also just type hai
# Bot: Offering support for Adverse drug reaction, Blood pressure, Hospitals and Pharmacies
#
#
# Speak...
# Stop.
# You :  and then you can say how
# Bot: I can guide you through Adverse drug reaction list, Blood pressure tracking, Hospitals and Pharmacies
#
#
# Speak...
# Stop.
# You :  isn't it is that's how
# Bot: Good to see you again
#
#
# Speak...
# Stop.
# You :  respond command response that's how this
# Bot: My pleasure
#
#
# Speak...
# Stop.
# You :  right let's say I will say
# Bot: Good to see you again
#
#
# Speak...
# Stop.
# You :  about my
# Bot: Hello, thanks for asking
#
#
# Speak...
# Stop.
# You :  light
# Bot: Good to see you again
#
#
# Speak...
# Stop.
# You :  so what should be the next response
# Bot: I can guide you through Adverse drug reaction list, Blood pressure tracking, Hospitals and Pharmacies
#
#
# Speak...
# Stop.
# You :  ok sure
# Bot: Hello, thanks for asking
#
#
# Speak...
# Stop.
# You :  PNR number isn't it all you can say
# Bot: I can guide you through Adverse drug reaction list, Blood pressure tracking, Hospitals and Pharmacies
#
#
# Speak...
# Stop.
# You :  all you can say it's a 6 digit PNR number
# Bot: I can guide you through Adverse drug reaction list, Blood pressure tracking, Hospitals and Pharmacies
#
#
# Speak...
# Stop.
# You :  that's how you must be
# Bot: Offering support for Adverse drug reaction, Blood pressure, Hospitals and Pharmacies
#
#
# Speak...
# Stop.
# You :  mutation and combination of commands responses
# Bot: Hello, thanks for asking
#
#
# Speak...
# Stop.
# You :  and this will be stored as one of the file in command got a JSON
# Bot: Navigating to Adverse drug reaction module
#
#
# Speak...
# Stop.
# You :  anything that would be come as a input from the user
# Bot: My pleasure
#
#
# Speak...
# Stop.
# You :  you have assumed right then your chatbot is not going
# Bot: I can guide you through Adverse drug reaction list, Blood pressure tracking, Hospitals and Pharmacies
#
#
# Speak...
# Stop.
# You :  for the airline chatbot if you will be asking
# Bot: Happy to help!
#
#
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# You :  right
# Bot: Hello, thanks for asking
#
#
# Speak...
# Stop.
# You :  asking this so it will be out of the contacts for that chatbot then
# Bot: My pleasure
#
#
# Speak...
# Stop.
# You :  cancer
# Bot: Good to see you again
#
#
# Speak...
# Stop.
# You :  thanks you again
# Bot: My pleasure
#
#
# Speak...
# Stop.
# You :  means that is not getting you
# Bot: Happy to help!
#
#
# Speak...
# Stop.
# You :  these responses you can of course feed into this command on this and that
# Bot: Offering support for Adverse drug reaction, Blood pressure, Hospitals and Pharmacies
#
#
# Speak...
# Stop.
# You :  aur would go
# Bot: Hello, thanks for asking
#
#
# Speak...
# Stop.
# You :  contact and of course you can say this
# Bot: Offering support for Adverse drug reaction, Blood pressure, Hospitals and Pharmacies
#
#
# Speak...
# Stop.
# You :  doubt anyone would have about command for JSON or was not pickle
# Bot: Hello, thanks for asking
#
#
# Speak...
# Stop.
# You :  ok if you do please please please let me
# Bot: I can guide you through Adverse drug reaction list, Blood pressure tracking, Hospitals and Pharmacies
#
#
# Speak...
# Stop.
# You :  will have class is not people now what is this is not pickle so gai Steel
# Bot: Offering support for Adverse drug reaction, Blood pressure, Hospitals and Pharmacies
#
#
# Speak...
# Stop.
# You :  example of a line parallel just to make your mind
# Bot: Navigating to Adverse drug reaction module
#
#
# Speak...
# Stop.
# You :  ok
# Bot: Hi there, how can I help?
#
#
# Speak...
# Stop.
# You :  your airline reservation chatbot would need to
# Bot: Hello, thanks for asking
#
#
# Speak...
# Stop.
# You :  for example flight status
# Bot: Hello, thanks for asking
#
#
# Speak...
# Stop.
# You :  so she now again you know Yasmeen you need to make this a sure
# Bot: Bye! Come back again soon.
#
#
# Speak...
# Stop.
# You :  hai
# Bot: Hello, thanks for asking
#
#
# Speak...
# Stop.
# You :  no so the no it can be knw
# Bot: I can guide you through Adverse drug reaction list, Blood pressure tracking, Hospitals and Pharmacies
#
#
# Speak...
# Stop.
# You :  now you are the one who is going to you know tell your
# Bot: Hello, thanks for asking
#
#
# Speak...
# Stop.
# You :  many words and sort of words it could be there and that is the reason you have watch.pk
# Bot: I can guide you through Adverse drug reaction list, Blood pressure tracking, Hospitals and Pharmacies
#
#
# Speak...
# Stop.
# ...
#
#
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# You :  and then you'll have this
# Bot: I can guide you through Adverse drug reaction list, Blood pressure tracking, Hospitals and Pharmacies
#
#
# Speak...
# Stop.
# You :  so please understand this getresponse is another user defined
# Bot: Hello, thanks for asking
#
#
# Speak...
# Stop.
# You :  how to pass our all the commands and paste the pond this
# Bot: Good to see you again
#
#
# Speak...
# Stop.
# You :  pass to the messages
# Bot: Good to see you again
#
#
# Speak...
# Stop.
# You :  the message
# Bot: Hi there, how can I help?
#
#
# Speak...
# Stop.
# You :  chatbot respond this message will be pass on
# Bot: Hi there, how can I help?
#
#
# Speak...
# Stop.
# You :  ok applying with the predictive model then this message will belong
# Bot: Hello, thanks for asking
#
#
# Speak...
# Stop.
# You :  you remember I told you that number of classes you to have right to based upon this
# Bot: Any time!
#
#
# Speak...
# Stop.
# You :  asset classes would be predicted based upon that classes
# Bot: My pleasure
#
#
# Speak...
# Stop.
# You :  what the response
# Bot: Offering support for Adverse drug reaction, Blood pressure, Hospitals and Pharmacies
#
#
# Speak...
# Stop.
# You :  entity response will get under this and then you will get the release
# Bot: Hi there, how can I help?
#
#
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# You :  then please used
# Bot: Hi there, how can I help?
#
#
# Speak...
# Stop.
# You :  please install this to libraries afterwards
# Bot: Hi there, how can I help?
#
#
# Speak...
# Stop.
# You :  speech recognition and Pi audio song let me tell you this
# Bot: I can guide you through Adverse drug reaction list, Blood pressure tracking, Hospitals and Pharmacies
#
#
# Speak...
# Stop.
# You :  libraries it is nothing got to do with machine learning and these libraries will help
# Bot: I can guide you through Adverse drug reaction list, Blood pressure tracking, Hospitals and Pharmacies
#
#
# Speak...
# Stop.
# You :  nice your voice to your headset on speaker right
# Bot: See you!
#
#
# Speak...
# Stop.
# You :  will be recognised by your receiver and will be converted to the text
# Bot: Have a nice day
#
#
# Speak...
# Stop.
# You :  vision and Pi audio it will go hand and hand ok parallel it will be working
# Bot: Hello, thanks for asking
#
#
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# You :  have you done till here let me know
# Bot: I can guide you through Adverse drug reaction list, Blood pressure tracking, Hospitals and Pharmacies
#
#
# Speak...
# Stop.
# You :  once you have done till here let me know
# Bot: I can guide you through Adverse drug reaction list, Blood pressure tracking, Hospitals and Pharmacies
#
#
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# You :  running setup.py
# Bot: Hi there, how can I help?
#
#
# Speak...
# Stop.
# You :  ok
# Bot: Hello, thanks for asking
#
#
# Speak...
# Stop.
# You :  Airtel bill pay audio
# Bot: Hi there, how can I help?
#
#
# Speak...
# Stop.
# You :  ok so Mehul has head guys so please
# Bot: Good to see you again
#
#
# Speak...
# Stop.
# You :  and maybe you got the answer
# Bot: Hello, thanks for asking
#
#
# Speak...
# Stop.
# You :  set PIP install PIP Windows and it will work
# Bot: Hi there, how can I help?
#
#
# Speak...
# Stop.
# You :  try this and let me know if it is still you would have any issue
# Bot: I can guide you through Adverse drug reaction list, Blood pressure tracking, Hospitals and Pharmacies
#
#
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# You :  guys let me know if you have done
# Bot: I can guide you through Adverse drug reaction list, Blood pressure tracking, Hospitals and Pharmacies
#
#
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# You :  bhaiya Paise Ki Baat Jab Aati Hai Na
# Bot: Good to see you again
#
#
# Speak...
# Stop.
# You :  dimag Nahin Lagta Hai FIR
# Bot: Hello, thanks for asking
#
#
# Speak...
# Stop.
# You :  mujhe laga Tumne to ab tak kamane bhi start kar diya Honge Yaar Ab poochh kar Legi bhabhi
# Bot: Hi there, how can I help?
#
#
# Speak...
# Stop.
# You :  are you
# Bot: Hi there, how can I help?
#
#
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# You :  Sab Kuchh Bhul Jaate Hain Ki susu Sahab
# Bot: Good to see you again
#
#
# Speak...
# Stop.
# You :  are yaar bahut badhiya Movie thi
# Bot: Good to see you again
#
#
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# You :  Achcha
# Bot: Hi there, how can I help?
#
#
# Speak...
# Stop.
# You :  Nahin Ham Logon Ne cal yah wali Matlab Ki movie ham log Ne you decide kara tha Ham aur se
# Bot: I can guide you through Adverse drug reaction list, Blood pressure tracking, Hospitals and Pharmacies
#
#
# Speak...
# Stop.
# You :  abhi Bade ki bhasha mein
# Bot: Hi there, how can I help?
#
#
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# You :  Kyon Nahin Hui Puri to
# Bot: Hi there, how can I help?
#
#
# Speak...
# Stop.
# You :  kaun si dekhte hain yah
# Bot: Hello, thanks for asking
#
#
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# You :  Telegram per karte hain FIR
# Bot: Hi there, how can I help?
#
#
# Speak...
# Stop.
# You :  main
# Bot: Hello, thanks for asking
#
#
# Speak...
# Stop.
# You :  great Indian murder aur ek human to main pahle bat Indian mother dekh li
# Bot: Good to see you again
#
#
# Speak...
# Stop.
# You :  chalo phir theek hai Padega
# Bot: Hi there, how can I help?
#
#
# Speak...
# Stop.
# You :  kya suspense suspense hai
# Bot: Good to see you again
#
#
# Speak...
# Stop.
# You :  vah to pata hai mere ko
# Bot: Hello, thanks for asking
#
#
# Speak...
# Stop.
# You :  Chalo Bulava dekhunga Mein web series
# Bot: Hello, thanks for asking
#
#
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# You :  han Bata rahe the
# Bot: Good to see you again
#
#
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# You :  Tum Bolo mausi ko mat do unko bolo na ghar mein
# Bot: Good to see you again
#
#
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# You :  chal beta theek hai main Mila Ta hun ya Bula rahe the Mujhe
# Bot: Hi there, how can I help?
#
#
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# You :  sugar is a people who have
# Bot: Hi there, how can I help?
#
#
# Speak...
# Stop.
# You :  tell me that this got installed
# Bot: Happy to help!
#
#
# Speak...
# Stop.
# You :  speech recognition
# Bot: Good to see you again
#
#
# Speak...
# Stop.
# You :  ok ok so now just hold on OK will come back to this let's test
# Bot: Any time!
#
#
# Speak...
# Stop.
# You :  possible that in your case you won't need that too
# Bot: Any time!
#
#
# Speak...
# Stop.
# You :  so as of now whatever you have done till till this moment
# Bot: See you!
#
#
# Speak...
# Stop.
# You :  no I don't worry now we are in our last
# Bot: Hello, thanks for asking
#
#
# Speak...
# Stop.
# You :  last you know block of code please understand this
# Bot: Good to see you again
#
#
# Speak...
# Stop.
# You :  so what are we going to do we are just going to take our in
# Bot: Hello, thanks for asking
#
#
# Speak...
# Stop.
# You :  do whatever we say
# Bot: Good to see you again
#
#
# Speak...
# Stop.
# You :  speak
# Bot: Hi there, how can I help?
#
#
# Speak...
# Stop.
# You :  with our microphone
# Bot: Hi there, how can I help?
#
#
# Speak...
# Stop.
# You :  our chatbot ok
# Bot: Hi there, how can I help?
#
#
# Speak...
# Stop.
# You :  what will listen
# Bot: I can guide you through Adverse drug reaction list, Blood pressure tracking, Hospitals and Pharmacies
#
#
# Speak...
# Stop.
# You :  agent source
# Bot: Hello, thanks for asking
#
#
# Speak...
# Stop.
# You :  it will
# Bot: Good to see you again
#
#
# Speak...
# Stop.
# You :  go ahead with all the functions and methods you have created
# Bot: I can guide you through Adverse drug reaction list, Blood pressure tracking, Hospitals and Pharmacies
#
#
# Speak...
# Stop.
# You :  ok so whatever you said it will be just convert
# Bot: I can guide you through Adverse drug reaction list, Blood pressure tracking, Hospitals and Pharmacies
#
#
# Speak...
# Stop.
# You :  it is for the English language chatbot so we are expecting it for
# Bot: Hello, thanks for asking
#
#
# Speak...
# Stop.
# You :  check that the text will be again
# Bot: My pleasure
#
#
# Speak...
# Stop.
# You :  into this
# Bot: Hi there, how can I help?
#
#
# Speak...
# Stop.
# You :  you have created here and now if you can see guys this
# Bot: I can guide you through Adverse drug reaction list, Blood pressure tracking, Hospitals and Pharmacies
#
#
# Speak...
# Stop.
# You :  you know
# Bot: Hi there, how can I help?
#
#
# Speak...
# Stop.
# You :  period as an input called message this argument right
# Bot: Good to see you again
#
#
# Speak...
# Stop.
# You :  will be called
# Bot: Good to see you again
#
#
# Speak...
# Stop.
# You :  cause if you can see this will go up then get response will be called this from
# Bot: Offering support for Adverse drug reaction, Blood pressure, Hospitals and Pharmacies
#
#
# Speak...
# Stop.
# You :  once project class will be called this function will be
# Bot: Good to see you again
#
#
# Speak...
# Stop.
# You :  are you getting my point
# Bot: Good to see you again
#
#
# Speak...
# Stop.
# You :  first this
# Bot: Hello, thanks for asking
#
#
# Speak...
# Stop.
# You :  then this show that you must understand how these functions are inter
# Bot: Hello, thanks for asking
#
#
# Speak...
# Stop.
# You :  have you got my point everyone
# Bot: Offering support for Adverse drug reaction, Blood pressure, Hospitals and Pharmacies
#
#
# Speak...
# Stop.
# You :  hair we only use only call one function
# Bot: Hi there, how can I help?
#
#
# Speak...
# Stop.
# You :  why because eventually you your problem statement says
# Bot: Hi there, how can I help?
#
#
# Speak...
# Stop.
# You :  it says that whatever you will be saying you must get the
# Bot: Happy to help!
#
#
# Speak...
# Stop.
# You :  what is the whole idea of chatbot is the reason now
# Bot: Offering support for Adverse drug reaction, Blood pressure, Hospitals and Pharmacies
#
#
# Speak...
# Stop.
# You :  more couple of things like
# Bot: Good to see you again
#
#
# Speak...
# Stop.
# You :  you will get the instruction speak then only you have to speak
# Bot: Offering support for Adverse drug reaction, Blood pressure, Hospitals and Pharmacies
#
#
# Speak...
# Stop.
# You :  whenever you say speak then only you can say you can say a something on
# Bot: I can guide you through Adverse drug reaction list, Blood pressure tracking, Hospitals and Pharmacies
#
#
# Speak...
# Stop.
# You :  then it will be it will be telling you stop
# Bot: I can guide you through Adverse drug reaction list, Blood pressure tracking, Hospitals and Pharmacies
#
#
# Speak...
# Stop.
# You :  tell you stop it means that it will record
# Bot: Happy to help!
#
#
# Speak...
# Stop.
# You :  that doesn't mean that it will record your voice
# Bot: Any time!
#
#
# Speak...
# Stop.
# You :  still here everyone is clear
# Bot: Hello, thanks for asking
#
#
# Speak...
# Stop.
# You :  first of all it will be getting listen to the function call listen
# Bot: Navigating to Adverse drug reaction module
#
#
# Speak...
# Stop.
# You :  listen will be coming from the library called this
# Bot: Hi there, how can I help?
#
#
# Speak...
# Stop.
# You :  the method it will hold all this you never listen and you recognise Google is all
# Bot: I can guide you through Adverse drug reaction list, Blood pressure tracking, Hospitals and Pharmacies
#
#
# Speak...
# Stop.
# You :  Google will you will convert your audio to text into the language in
# Bot: Have a nice day
#
#
# Speak...
# Stop.
# You :  will be a passing on hair and you will get what response is like
# Bot: I can guide you through Adverse drug reaction list, Blood pressure tracking, Hospitals and Pharmacies
#
#
# Speak...
# Stop.
# You :  if at all you will be speaking anything which will go beyond the
# Bot: Offering support for Adverse drug reaction, Blood pressure, Hospitals and Pharmacies
#
#
# Speak...
# Stop.
# You :  you will get this could not understand your audio please
# Bot: Offering support for Adverse drug reaction, Blood pressure, Hospitals and Pharmacies
#
#
# Speak...
# Stop.
# You :  have you got this
# Bot: I can guide you through Adverse drug reaction list, Blood pressure tracking, Hospitals and Pharmacies
#
#
# Speak...
# Stop.
# You :  everyone
# Bot: Hi there, how can I help?
#
#
# Speak...
# Stop.
# You :  so let's try this final block of code
# Bot: Happy to help!
#
#
# Speak...
# Stop.
# You :  if it won't then you must get this and that
# Bot: My pleasure
#
#
# Speak...
# Stop.
# You :  let's see
# Bot: See you!
#
#
# Speak...
# Stop.
# You :  if it will be executed it will come like this speak you should speak
# Bot: Offering support for Adverse drug reaction, Blood pressure, Hospitals and Pharmacies
#
#
# Speak...
# Stop.
# You :  then you will be getting this
# Bot: I can guide you through Adverse drug reaction list, Blood pressure tracking, Hospitals and Pharmacies
#
#
# Speak...
# Stop.
# You :  let me know if its working
# Bot: Happy to help!
#
#
# Speak...
# Stop.
# You :  very good speak to your headphone hello
# Bot: Hello, thanks for asking
#
#
# Speak...
# Stop.
# You :  speak to your headphone
# Bot: Good to see you again
#
#
# Speak...
# Stop.
# You :  sorry
# Bot: Good to see you again
#
#
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# You :  sugar is
# Bot: Good to see you again
#
#
# Speak...
# Stop.
# You :  this line I can guide you through adverse drug reaction list
# Bot: Navigating to Adverse drug reaction module
#
#
# Speak...
# Stop.
# You :  class
# Bot: Hello, thanks for asking
#
#
# Speak...
# Stop.
# You :  Play Store tracking it is another class
# Bot: Good to see you again
#
#
# Speak...
# Stop.
# You :  another class pharmacies the class
# Bot: Please provide pharmacy name
#
#
# Speak...
# Stop.
# You :  ok so you can try speaking different thing out have it
# Bot: I can guide you through Adverse drug reaction list, Blood pressure tracking, Hospitals and Pharmacies
#
#
# Speak...
# Stop.
# You :  don't worry about the answers ok
# Bot: Hello, thanks for asking
#
#
# Speak...
# Stop.
# You :  can you tell me
# Bot: Offering support for Adverse drug reaction, Blood pressure, Hospitals and Pharmacies
#
#
# Speak...
# Stop.
# You :  list of
# Bot: Navigating to Adverse drug reaction module
#
#
# Speak...
# Stop.
# You :  can you tell me the list of hospitals
# Bot: I can guide you through Adverse drug reaction list, Blood pressure tracking, Hospitals and Pharmacies
#
#
# Speak...
# Stop.
# You :  ok how can I get drug reaction list
# Bot: Navigating to Adverse drug reaction module
#
#
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
# Stop.
# Could not understand your audio, PLease try again!
# Speak...
